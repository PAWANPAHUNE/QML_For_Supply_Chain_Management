# %%
import sys, getopt, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler

from qiskit.circuit.library import PauliFeatureMap, RealAmplitudes, ZZFeatureMap
from qiskit_machine_learning.algorithms import VQC
from qiskit_machine_learning.optimizers import L_BFGS_B

root_folder = 'VQC'
### Globals
# For reproducibility
np.random.seed(42)

# Fixed feature sizes
NUM_FEATURES = 3

# Quantum circuit parameters
IF_PAULI_FEATURE_MAP_LIST = [True, False]
FEATURE_MAP_REPS_LIST = [1, 2, 3, 4, 5]
ANSATZ_REPS_LIST = [1, 2, 3, 4, 5]
ENTANGLEMENT_LIST = ['linear', 'full', 'circular']

# Training hyperparameters
LOSS_FUNCTION = 'cross_entropy'

# Training repetition parameters
N_REPEATS = 10

# Data conf
CLASSIFIER_THRESHOLD = 19

def prepare_dataset_k_fold(X_train, y_train, X_test, y_test):
    """
    Prepare dataset by scaling features.
    """
    # Scale training and test sets separately
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(np.vstack([X_train, X_test]))  # Fit on combined data for consistency
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    return X_train_scaled, y_train, X_test_scaled, y_test, None, None

def reconfig_quantum_kernel_vqc(if_pauli_feature_map, feature_reps, ansatz_reps, entangle, objective_func_vals):
    """
        Create a quantum kernel
        vqc = VQC(C=20.0, epsilon=0.2, quantum_kernel=kernel)

        Args:
            if_pauli_feature_map: If True, use a Pauli feature map, else ZZ feature map.
            feature_reps: Number of repetitions of quantum circuit for a feature map.
            ansatz_reps: Number of repetitions of quantum circuit for the ansatz.
            entangle: Entanglement type of the feature map.
            objective_func_vals: List to store the objective function values during training.

        Returns:
            qsvr: quantum kernel
    """
    # Define callback function for plotting the training progress
    def callback_graph(weights, obj_func_eval):
        # clear_output(wait=True)
        objective_func_vals.append(obj_func_eval)
        print(f"Iteration: {len(objective_func_vals)}, Objective function value: {obj_func_eval}")
        #plt.rcParams["figure.figsize"] = (12, 6)
        #plt.xlabel("Iteration")
        #plt.ylabel("Objective function value")
        #plt.plot(range(len(objective_func_vals)), objective_func_vals)
        #plt.show()

    # Configure feature map
    if if_pauli_feature_map:
        feature_map = PauliFeatureMap(feature_dimension=NUM_FEATURES, reps=feature_reps, entanglement=entangle)
    else:
        feature_map = ZZFeatureMap(feature_dimension=NUM_FEATURES, reps=feature_reps, entanglement=entangle)

    # Configure ansatz
    ansatz = RealAmplitudes(num_qubits=NUM_FEATURES, reps=ansatz_reps)

    # Configure optimizer
    optimizer = L_BFGS_B(ftol=0.000001, maxiter=20)

    return VQC(feature_map=feature_map,
               ansatz=ansatz,
               optimizer=optimizer,
               callback=callback_graph,
               loss=LOSS_FUNCTION,
               )

def train_vqc(vqc, X_train, y_train, X_test):
    """
        Train based on X_train/y_train (after scaling), return prediction from X_test

        Args:
            vqc: quantum kernel
            X_train:
            y_train
            X_test

        Returns:
    """
    vqc.fit(X_train, y_train)
    return vqc.predict(X_train), vqc.predict(X_test)

def get_arguments(argvs):
    _entangle = ''
    _feature_map_reps = ''
    _ansatz_reps = ''
    _if_pauli_feature = True
    try:
        opts, args = getopt.getopt(argvs, "h:e:f:a:p:", ["entangle=", "feature_map_reps=", "ansatz_reps=", "if_pauli_feature="])
    except getopt.GetoptError:
        print(root_folder + '.py -e <entangle> -f <feature_map_reps> -a <ansatz_reps> -p <if_pauli_feature>')
        sys.exit(2)
    for opt, arg in opts:
        if opt == '-h':
            print(root_folder + '.py -e <entangle> -f <feature_map_reps> -a <ansatz_reps> -p <if_pauli_feature>')
            sys.exit()
        elif opt in ("-e", "--entangle"):
            _entangle = arg
        elif opt in ("-f", "--feature_map_reps"):
            _feature_map_reps = int(arg)
        elif opt in ("-a", "--ansatz_reps"):
            _ansatz_reps = int(arg)
        elif opt in ("-p", "--if_pauli_feature"):
            _if_pauli_feature = eval(arg)
    return _entangle, _feature_map_reps, _ansatz_reps, _if_pauli_feature

if __name__ == "__main__":
    date = '05_31_25_0'
    if not os.path.exists(f'{root_folder}/result'):
        os.makedirs(f'{root_folder}/result')
    if not os.path.exists(f'{root_folder}/logs'):
        os.makedirs(f'{root_folder}/logs')
    try:
        from IPython import get_ipython
        if get_ipython() is not None:
            tmp1, tmp2, tmp3, tmp4 = 'linear', 1, 1, True  # Default values
        else:
            tmp1, tmp2, tmp3, tmp4 = get_arguments(sys.argv[1:])
    except ImportError:
        tmp1, tmp2, tmp3, tmp4 = get_arguments(sys.argv[1:])
    if tmp1 != '':
        ENTANGLEMENT_LIST = [tmp1]
    if tmp2 != '':
        FEATURE_MAP_REPS_LIST = [tmp2]
    if tmp3 != '':
        ANSATZ_REPS_LIST = [tmp3]
    if tmp4 != '':
        IF_PAULI_FEATURE_MAP_LIST = [tmp4]
    print(f"\nFEATURE_MAP_REPS_LIST={FEATURE_MAP_REPS_LIST} "
          f"ANSATZ_REPS_LIST={ANSATZ_REPS_LIST} "
          f"ENTANGLEMENT_LIST={ENTANGLEMENT_LIST} "
          f"IF_PAULI_FEATURE_MAP_LIST={IF_PAULI_FEATURE_MAP_LIST} "
          f"date={date}")
    if len(FEATURE_MAP_REPS_LIST) == 1:
        FEATURE_MAP_REPS_LIST_NAME = FEATURE_MAP_REPS_LIST[0]
    else:
        FEATURE_MAP_REPS_LIST_NAME = FEATURE_MAP_REPS_LIST
    if len(ANSATZ_REPS_LIST) == 1:
        ANSATZ_REPS_LIST_NAME = ANSATZ_REPS_LIST[0]
    else:
        ANSATZ_REPS_LIST_NAME = ANSATZ_REPS_LIST
    if len(ENTANGLEMENT_LIST) == 1:
        ENTANGLEMENT_LIST_NAME = ENTANGLEMENT_LIST[0]
    else:
        ENTANGLEMENT_LIST_NAME = ENTANGLEMENT_LIST
    if len(IF_PAULI_FEATURE_MAP_LIST) == 1:
        IF_PAULI_FEATURE_MAP_LIST_NAME = IF_PAULI_FEATURE_MAP_LIST[0]
    else:
        IF_PAULI_FEATURE_MAP_LIST_NAME = IF_PAULI_FEATURE_MAP_LIST
    IF_PAULI_FEATURE_MAP_LIST_NAME = str(IF_PAULI_FEATURE_MAP_LIST_NAME).replace('False', 'ZZ').replace('True', 'Pauli')
    file_name = f'{root_folder}/result/FMR_{FEATURE_MAP_REPS_LIST_NAME}_AR_{ANSATZ_REPS_LIST_NAME}_E_{ENTANGLEMENT_LIST_NAME}_P_{IF_PAULI_FEATURE_MAP_LIST_NAME}_{date}.csv'
    print('\nTo be saved to', file_name)

    print("\n--- Loading and Preprocessing Data ---")

    train_df = pd.read_csv("Training_Top3Features.csv")
    test_df = pd.read_csv("Testing_Top3Features.csv")
    X_train = train_df.drop('went_on_backorder', axis=1).values
    y_train = train_df['went_on_backorder'].values
    X_test = test_df.drop('went_on_backorder', axis=1).values
    y_test = test_df['went_on_backorder'].values

    print('Training data size: ', X_train.shape[0])
    print('Testing data size: ', X_test.shape[0])

    df = pd.DataFrame(columns=['feature_map_name', 'feature_map_reps', 'ansatz_reps', 'entanglement',
                               'element test', 'actual test', 'predicted test',
                               'element train', 'actual train', 'predicted train',
                               'train_accuracy', 'test_accuracy', 'train_f1', 'test_f1',
                               'train_recall', 'test_recall', 'train_precision', 'test_precision',
                               'train_cm', 'test_cm'])

    print("\n--- Start Training Loop ---")

    for i in range(N_REPEATS):
        X_train_scaled, y_train_scaled, X_test_scaled, y_test_scaled, element_test, element_train = prepare_dataset_k_fold(X_train, y_train, X_test, y_test)
        for if_pauli_feature_map in IF_PAULI_FEATURE_MAP_LIST:
            for feature_map_reps in FEATURE_MAP_REPS_LIST:
                for ansatz_reps in ANSATZ_REPS_LIST:
                    for entanglement in ENTANGLEMENT_LIST:
                        if if_pauli_feature_map:
                            feature_map_name = 'Pauli'
                        else:
                            feature_map_name = 'ZZ'
                        print(f'\n--- Result of training {i+1} ---')
                        print(f'feature_map_name: {feature_map_name} '
                              f'feature_map_reps: {feature_map_reps} '
                              f'ansatz_reps: {ansatz_reps} '
                              f'entanglement: {entanglement} '
                              f'element test: {element_test if element_test is not None else "N/A"}')
                        # conf kernel
                        objective_func_vals = []
                        vqc = reconfig_quantum_kernel_vqc(if_pauli_feature_map=if_pauli_feature_map,
                                                           feature_reps=feature_map_reps,
                                                           ansatz_reps=ansatz_reps,
                                                           entangle=entanglement,
                                                           objective_func_vals=objective_func_vals,
                                                           )

                        # train
                        predict_train, predict_test = train_vqc(vqc, X_train_scaled, y_train_scaled, X_test_scaled)

                        # some conversions
                        all_preds = np.atleast_1d(predict_test)
                        all_targets = np.atleast_1d(y_test_scaled)
                        all_preds_train = np.array(predict_train)
                        all_targets_train = np.array(y_train_scaled)

                        # Calculate metrics
                        train_accuracy = accuracy_score(all_targets_train, all_preds_train)
                        test_accuracy = accuracy_score(all_targets, all_preds)
                        train_f1 = f1_score(all_targets_train, all_preds_train, zero_division=0)
                        test_f1 = f1_score(all_targets, all_preds, zero_division=0)
                        train_recall = recall_score(all_targets_train, all_preds_train, zero_division=0)
                        test_recall = recall_score(all_targets, all_preds, zero_division=0)
                        train_precision = precision_score(all_targets_train, all_preds_train, zero_division=0)
                        test_precision = precision_score(all_targets, all_preds, zero_division=0)
                        train_cm = confusion_matrix(all_targets_train, all_preds_train)
                        test_cm = confusion_matrix(all_targets, all_preds, labels=[0, 1])

                        # Print metrics
                        print(f"Train Accuracy: {train_accuracy:.4f}")
                        print(f"Test Accuracy: {test_accuracy:.4f}")
                        print(f"Train F1 Score: {train_f1:.4f}")
                        print(f"Test F1 Score: {test_f1:.4f}")
                        print(f"Train Recall: {train_recall:.4f}")
                        print(f"Test Recall: {test_recall:.4f}")
                        print(f"Train Precision: {train_precision:.4f}")
                        print(f"Test Precision: {test_precision:.4f}")
                        print(f"Train Confusion Matrix:\n{train_cm}")
                        print(f"Test Confusion Matrix:\n{test_cm}")

                        # save data
                        new_row = {'feature_map_name': feature_map_name,
                                   'feature_map_reps': feature_map_reps,
                                   'ansatz_reps': ansatz_reps,
                                   'entanglement': entanglement,
                                   'element test': element_test if element_test is not None else 'N/A',
                                   'actual test': np.array(all_targets).flatten(),
                                   'predicted test': np.array(all_preds).flatten(),
                                   'element train': element_train if element_train is not None else 'N/A',
                                   'actual train': np.array(all_targets_train).flatten(),
                                   'predicted train': np.array(all_preds_train).flatten(),
                                   'train_accuracy': train_accuracy,
                                   'test_accuracy': test_accuracy,
                                   'train_f1': train_f1,
                                   'test_f1': test_f1,
                                   'train_recall': train_recall,
                                   'test_recall': test_recall,
                                   'train_precision': train_precision,
                                   'test_precision': test_precision,
                                   'train_cm': train_cm.tolist(),
                                   'test_cm': test_cm.tolist()}
                        df.loc[len(df)] = new_row
                        with np.printoptions(linewidth=10000):
                            df.to_csv(file_name, index=False)  # update csv every loop
                        df.at[0, "info"] = [f"DATASET: Training_Top3Features.csv, Testing_Top3Features.csv, LOSS: {LOSS_FUNCTION}"]
# Out:
# FEATURE_MAP_REPS_LIST=[1] ANSATZ_REPS_LIST=[1] ENTANGLEMENT_LIST=['linear'] IF_PAULI_FEATURE_MAP_LIST=[True] date=05_31_25_0
#
# To be saved to VQC/result/FMR_1_AR_1_E_linear_P_Pauli_05_31_25_0.csv
#
# --- Loading and Preprocessing Data ---
# Training data size:  10000
# Testing data size:  4000
#
# --- Start Training Loop ---
#
# --- Result of training 1 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0217935085742302
# Iteration: 2, Objective function value: 0.9993579424357271
# Iteration: 3, Objective function value: 0.988629053074912
# Iteration: 4, Objective function value: 0.9876665131521584
# Iteration: 5, Objective function value: 0.9877041315723847
# Iteration: 6, Objective function value: 0.9876548063999951
# Iteration: 7, Objective function value: 0.9876893644341206
# Iteration: 8, Objective function value: 0.987650395806204
# Iteration: 9, Objective function value: 0.98768622157332
# Iteration: 10, Objective function value: 0.987648230251046
# Iteration: 11, Objective function value: 0.9876829395979257
# Iteration: 12, Objective function value: 0.9876468283283669
# Iteration: 13, Objective function value: 0.987661219991473
# Iteration: 14, Objective function value: 0.9876466059693683
# Iteration: 15, Objective function value: 0.9876802854202473
# Iteration: 16, Objective function value: 0.9876460564800386
# Iteration: 17, Objective function value: 0.9876608504066863
# Iteration: 18, Objective function value: 0.9876461798661083
# Train Accuracy: 0.6228
# Test Accuracy: 0.6012
# Train F1 Score: 0.6145
# Test F1 Score: 0.5847
# Train Recall: 0.6012
# Test Recall: 0.5615
# Train Precision: 0.6283
# Test Precision: 0.6100
# Train Confusion Matrix:
# [[3222 1778]
#  [1994 3006]]
# Test Confusion Matrix:
# [[1282  718]
#  [ 877 1123]]
#
# --- Result of training 2 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.1213865572801236
# Iteration: 2, Objective function value: 1.1058708300133895
# Iteration: 3, Objective function value: 1.0480968790298422
# Iteration: 4, Objective function value: 1.0743414515061973
# Iteration: 5, Objective function value: 1.0401957151311516
# Iteration: 6, Objective function value: 1.0065868517109509
# Iteration: 7, Objective function value: 1.0778265848539492
# Iteration: 8, Objective function value: 0.9980672268884254
# Iteration: 9, Objective function value: 0.9915067263113999
# Iteration: 10, Objective function value: 0.9877017691123375
# Iteration: 11, Objective function value: 0.9876935752387024
# Iteration: 12, Objective function value: 0.9876124180344257
# Iteration: 13, Objective function value: 0.9865038094703094
# Iteration: 14, Objective function value: 0.971276635083362
# Iteration: 15, Objective function value: 1.0160842646160477
# Iteration: 16, Objective function value: 0.9616522075046667
# Iteration: 17, Objective function value: 0.9609384614991399
# Iteration: 18, Objective function value: 0.9540477643448126
# Iteration: 19, Objective function value: 0.9491036943408362
# Iteration: 20, Objective function value: 0.9485790497685964
# Iteration: 21, Objective function value: 1.0285552894870198
# Iteration: 22, Objective function value: 0.9485654156373101
# Iteration: 23, Objective function value: 0.9474514656878696
# Iteration: 24, Objective function value: 0.9471768402373411
# Iteration: 25, Objective function value: 0.9471408290877851
# Iteration: 26, Objective function value: 0.9471471847359116
# Iteration: 27, Objective function value: 0.9471408532593996
# Iteration: 28, Objective function value: 0.9471408532593996
# Iteration: 29, Objective function value: 0.9471408532593996
# Iteration: 30, Objective function value: 0.9471408532593996
# Train Accuracy: 0.6257
# Test Accuracy: 0.6150
# Train F1 Score: 0.6223
# Test F1 Score: 0.6133
# Train Recall: 0.6168
# Test Recall: 0.6105
# Train Precision: 0.6280
# Test Precision: 0.6160
# Train Confusion Matrix:
# [[3173 1827]
#  [1916 3084]]
# Test Confusion Matrix:
# [[1239  761]
#  [ 779 1221]]
#
# --- Result of training 3 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.1213187702475456
# Iteration: 2, Objective function value: 0.995728152917937
# Iteration: 3, Objective function value: 1.1050874495390914
# Iteration: 4, Objective function value: 0.977654877326862
# Iteration: 5, Objective function value: 0.960641268277838
# Iteration: 6, Objective function value: 0.9511300044625708
# Iteration: 7, Objective function value: 0.9499691068749418
# Iteration: 8, Objective function value: 0.9496413212869942
# Iteration: 9, Objective function value: 0.9496230882149442
# Iteration: 10, Objective function value: 0.9496310169854479
# Iteration: 11, Objective function value: 0.9496233351282999
# Iteration: 12, Objective function value: 0.9496231074449941
# Iteration: 13, Objective function value: 0.9496230898211561
# Iteration: 14, Objective function value: 0.9496230898211561
# Iteration: 15, Objective function value: 0.9496230898211561
# Iteration: 16, Objective function value: 0.9496230898211561
# Iteration: 17, Objective function value: 0.9496230898211561
# Train Accuracy: 0.6980
# Test Accuracy: 0.6797
# Train F1 Score: 0.7029
# Test F1 Score: 0.6861
# Train Recall: 0.7144
# Test Recall: 0.7000
# Train Precision: 0.6917
# Test Precision: 0.6728
# Train Confusion Matrix:
# [[3408 1592]
#  [1428 3572]]
# Test Confusion Matrix:
# [[1319  681]
#  [ 600 1400]]
#
# --- Result of training 4 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0430291673363905
# Iteration: 2, Objective function value: 0.990960503760786
# Iteration: 3, Objective function value: 0.9851181759410782
# Iteration: 4, Objective function value: 0.9802299902440532
# Iteration: 5, Objective function value: 0.9525176503025603
# Iteration: 6, Objective function value: 1.035818040014789
# Iteration: 7, Objective function value: 0.9544048540639755
# Iteration: 8, Objective function value: 0.9508365103728398
# Iteration: 9, Objective function value: 1.0192541001713895
# Iteration: 10, Objective function value: 0.9501356220996197
# Iteration: 11, Objective function value: 0.9476377715663319
# Iteration: 12, Objective function value: 0.9471855400431859
# Iteration: 13, Objective function value: 0.947170032230287
# Iteration: 14, Objective function value: 0.947163967238682
# Iteration: 15, Objective function value: 0.9471491440749822
# Iteration: 16, Objective function value: 0.9471489420845448
# Train Accuracy: 0.6264
# Test Accuracy: 0.6158
# Train F1 Score: 0.6232
# Test F1 Score: 0.6143
# Train Recall: 0.6178
# Test Recall: 0.6120
# Train Precision: 0.6286
# Test Precision: 0.6166
# Train Confusion Matrix:
# [[3175 1825]
#  [1911 3089]]
# Test Confusion Matrix:
# [[1239  761]
#  [ 776 1224]]
#
# --- Result of training 5 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0994677323411648
# Iteration: 2, Objective function value: 1.009404796185884
# Iteration: 3, Objective function value: 0.9804745897159511
# Iteration: 4, Objective function value: 0.9957355199430203
# Iteration: 5, Objective function value: 0.9801665231719562
# Iteration: 6, Objective function value: 0.9739358119641486
# Iteration: 7, Objective function value: 0.9761259417773519
# Iteration: 8, Objective function value: 0.9620769067091136
# Iteration: 9, Objective function value: 0.9612656945434573
# Iteration: 10, Objective function value: 0.961210061606744
# Iteration: 11, Objective function value: 0.9609756780223275
# Iteration: 12, Objective function value: 0.9596682053521368
# Iteration: 13, Objective function value: 1.0034528977141441
# Iteration: 14, Objective function value: 0.9590296993423537
# Iteration: 15, Objective function value: 0.9521740670077383
# Iteration: 16, Objective function value: 0.9496746075622177
# Iteration: 17, Objective function value: 0.9496452420731383
# Iteration: 18, Objective function value: 0.949635378244711
# Iteration: 19, Objective function value: 0.9496303220229387
# Iteration: 20, Objective function value: 0.9496292481641471
# Iteration: 21, Objective function value: 0.9496289249733741
# Train Accuracy: 0.6948
# Test Accuracy: 0.6770
# Train F1 Score: 0.6985
# Test F1 Score: 0.6822
# Train Recall: 0.7070
# Test Recall: 0.6935
# Train Precision: 0.6902
# Test Precision: 0.6713
# Train Confusion Matrix:
# [[3413 1587]
#  [1465 3535]]
# Test Confusion Matrix:
# [[1321  679]
#  [ 613 1387]]
#
# --- Result of training 6 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0600709615955681
# Iteration: 2, Objective function value: 0.98618856503721
# Iteration: 3, Objective function value: 0.9754327778844869
# Iteration: 4, Objective function value: 0.9604083355513047
# Iteration: 5, Objective function value: 0.9584182935865465
# Iteration: 6, Objective function value: 0.951824219163381
# Iteration: 7, Objective function value: 0.9511976958034207
# Iteration: 8, Objective function value: 0.949720165107871
# Iteration: 9, Objective function value: 0.9496595577420205
# Iteration: 10, Objective function value: 0.9496760241569827
# Iteration: 11, Objective function value: 0.9496556211106361
# Iteration: 12, Objective function value: 0.9496377049424344
# Iteration: 13, Objective function value: 0.9496320317417946
# Iteration: 14, Objective function value: 0.9496293678184231
# Train Accuracy: 0.6948
# Test Accuracy: 0.6770
# Train F1 Score: 0.6985
# Test F1 Score: 0.6822
# Train Recall: 0.7070
# Test Recall: 0.6935
# Train Precision: 0.6902
# Test Precision: 0.6713
# Train Confusion Matrix:
# [[3413 1587]
#  [1465 3535]]
# Test Confusion Matrix:
# [[1321  679]
#  [ 613 1387]]
#
# --- Result of training 7 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0420544128297047
# Iteration: 2, Objective function value: 0.978056885056715
# Iteration: 3, Objective function value: 0.9676320418966178
# Iteration: 4, Objective function value: 0.9684657013712731
# Iteration: 5, Objective function value: 0.9513321150491192
# Iteration: 6, Objective function value: 0.9499848053605642
# Iteration: 7, Objective function value: 0.9496892079175246
# Iteration: 8, Objective function value: 0.9496445663354982
# Iteration: 9, Objective function value: 0.9496335047603613
# Iteration: 10, Objective function value: 0.9496285718466293
# Train Accuracy: 0.6948
# Test Accuracy: 0.6770
# Train F1 Score: 0.6985
# Test F1 Score: 0.6822
# Train Recall: 0.7070
# Test Recall: 0.6935
# Train Precision: 0.6902
# Test Precision: 0.6713
# Train Confusion Matrix:
# [[3413 1587]
#  [1465 3535]]
# Test Confusion Matrix:
# [[1321  679]
#  [ 613 1387]]
#
# --- Result of training 8 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0639311325641383
# Iteration: 2, Objective function value: 0.9920522900251836
# Iteration: 3, Objective function value: 0.9887290460311208
# Iteration: 4, Objective function value: 0.9870926598742595
# Iteration: 5, Objective function value: 0.9860514165332708
# Iteration: 6, Objective function value: 0.9787968047932031
# Iteration: 7, Objective function value: 0.9726144722449258
# Iteration: 8, Objective function value: 0.9658928629173064
# Iteration: 9, Objective function value: 0.9616326939471981
# Iteration: 10, Objective function value: 1.0908675963307028
# Iteration: 11, Objective function value: 1.0587440534306185
# Iteration: 12, Objective function value: 0.9614573140232293
# Iteration: 13, Objective function value: 0.9582750309599803
# Iteration: 14, Objective function value: 0.9522662301117891
# Iteration: 15, Objective function value: 0.950473618786266
# Iteration: 16, Objective function value: 0.9500208531571969
# Iteration: 17, Objective function value: 0.9497611756664043
# Iteration: 18, Objective function value: 0.9496708161074644
# Iteration: 19, Objective function value: 0.9496286205234832
# Iteration: 20, Objective function value: 0.9496292036269509
# Iteration: 21, Objective function value: 0.9496286245986816
# Iteration: 22, Objective function value: 0.9496286245986816
# Iteration: 23, Objective function value: 0.9496286245986816
# Iteration: 24, Objective function value: 0.9496286245986816
# Train Accuracy: 0.6949
# Test Accuracy: 0.6767
# Train F1 Score: 0.6985
# Test F1 Score: 0.6821
# Train Recall: 0.7070
# Test Recall: 0.6935
# Train Precision: 0.6903
# Test Precision: 0.6710
# Train Confusion Matrix:
# [[3414 1586]
#  [1465 3535]]
# Test Confusion Matrix:
# [[1320  680]
#  [ 613 1387]]
#
# --- Result of training 9 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.0426670802347537
# Iteration: 2, Objective function value: 0.985055134406186
# Iteration: 3, Objective function value: 0.9756172265960417
# Iteration: 4, Objective function value: 0.9567507650795256
# Iteration: 5, Objective function value: 0.9569093307899477
# Iteration: 6, Objective function value: 0.952781989083224
# Iteration: 7, Objective function value: 0.9527334845196572
# Iteration: 8, Objective function value: 0.9527348909712142
# Iteration: 9, Objective function value: 0.9527230921332126
# Iteration: 10, Objective function value: 0.9526652497264584
# Iteration: 11, Objective function value: 1.014211555524465
# Iteration: 12, Objective function value: 0.9526574123360824
# Iteration: 13, Objective function value: 0.9526493908620379
# Iteration: 14, Objective function value: 0.9637561121320792
# Iteration: 15, Objective function value: 0.9526344174182614
# Iteration: 16, Objective function value: 0.9526294260794026
# Iteration: 17, Objective function value: 0.9535539471615164
# Iteration: 18, Objective function value: 0.9525858327166056
# Iteration: 19, Objective function value: 0.9525747061305682
# Iteration: 20, Objective function value: 0.9525606232935595
# Iteration: 21, Objective function value: 0.9522379543865329
# Iteration: 22, Objective function value: 0.9507771966460971
# Iteration: 23, Objective function value: 0.9506172899623682
# Iteration: 24, Objective function value: 0.9500606699309515
# Iteration: 25, Objective function value: 0.9496581571070306
# Iteration: 26, Objective function value: 0.9496373653754306
# Iteration: 27, Objective function value: 0.9496326598100714
# Iteration: 28, Objective function value: 0.9496289692108654
# Train Accuracy: 0.6948
# Test Accuracy: 0.6770
# Train F1 Score: 0.6985
# Test F1 Score: 0.6822
# Train Recall: 0.7070
# Test Recall: 0.6935
# Train Precision: 0.6902
# Test Precision: 0.6713
# Train Confusion Matrix:
# [[3413 1587]
#  [1465 3535]]
# Test Confusion Matrix:
# [[1321  679]
#  [ 613 1387]]
#
# --- Result of training 10 ---
# feature_map_name: Pauli feature_map_reps: 1 ansatz_reps: 1 entanglement: linear element test: N/A
# Iteration: 1, Objective function value: 1.097349956007012
# Iteration: 2, Objective function value: 1.0193449917836155
# Iteration: 3, Objective function value: 1.0028984078719954
# Iteration: 4, Objective function value: 1.1729873422901655
# Iteration: 5, Objective function value: 0.9883974055756857
# Iteration: 6, Objective function value: 1.0323878242614073
# Iteration: 7, Objective function value: 0.9807447974454595
# Iteration: 8, Objective function value: 0.9634634593738829
# Iteration: 9, Objective function value: 0.9608288364415603
# Iteration: 10, Objective function value: 0.957615320717864
# Iteration: 11, Objective function value: 0.9549240797704391
# Iteration: 12, Objective function value: 0.9623512543140287
# Iteration: 13, Objective function value: 0.952423614384541
# Iteration: 14, Objective function value: 0.9554871416645463
# Iteration: 15, Objective function value: 0.9492873222161352
# Iteration: 16, Objective function value: 0.9474658182096946
# Iteration: 17, Objective function value: 0.9471249759788276
# Iteration: 18, Objective function value: 0.947089397148249
# Iteration: 19, Objective function value: 0.9471344473001085
# Iteration: 20, Objective function value: 0.947090348738198
# Iteration: 21, Objective function value: 0.9470894254315637
# Iteration: 22, Objective function value: 0.9470894254315637
# Iteration: 23, Objective function value: 0.9470894254315637
# Iteration: 24, Objective function value: 0.9470894254315637
# Iteration: 25, Objective function value: 0.9470894254315637
# Train Accuracy: 0.6234
# Test Accuracy: 0.6120
# Train F1 Score: 0.6189
# Test F1 Score: 0.6091
# Train Recall: 0.6116
# Test Recall: 0.6045
# Train Precision: 0.6264
# Test Precision: 0.6137
# Train Confusion Matrix:
# [[3176 1824]
#  [1942 3058]]
# Test Confusion Matrix:
# [[1239  761]
#  [ 791 1209]]
